# %%
#librerie da importare:

from urllib import request
import pandas as pd
from datetime import datetime
import json
import numpy as np
import pymongo
from pymongo import MongoClient
from json import dumps
import time
import json
from json import loads
import warnings
import io
warnings.filterwarnings("ignore")

# %%
url_pal = 'https://github.com/NightSkimmi/palazzetti_nba/raw/main/palazzetti_raw.csv'
df_palazzetti = pd.read_csv(url_pal, sep = ',', encoding='latin-1')
df_palazzetti
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
df_palazzetti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LEAGUE_ID           30 non-null     int64
#  1   TEAM_ID             30 non-null     int64
#  2   MIN_YEAR            30 non-null     int64
#  3   MAX_YEAR            30 non-null     int64
#  4   ABBREVIATION        30 non-null     object
#  5   NICKNAME            30 non-null     object
#  6   YEARFOUNDED         30 non-null     int64
#  7   CITY                30 non-null     object
#  8   ARENA               30 non-null     object
#  9   ARENACAPACITY       26 non-null     float64
#  10  OWNER               30 non-null     object
#  11  GENERALMANAGER      30 non-null     object
#  12  HEADCOACH           30 non-null     object
#  13  DLEAGUEAFFILIATION  30 non-null     object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 3.4+ KB

# %%
#Eliminazione di variabili non utili all'analisi
df_palazzetti.drop(columns = ['LEAGUE_ID','GENERALMANAGER','HEADCOACH','DLEAGUEAFFILIATION', 'OWNER'], inplace = True)

# %%
#Aggiornamento data
for i in range(0, 29):
    df_palazzetti['MAX_YEAR'] = 2022

# %%
# Completezza del dataset dei palazzetti
df_palazzetti.at[2, 'ARENACAPACITY'] = 16867
df_palazzetti.at[12, 'ARENACAPACITY'] = 17732
df_palazzetti.at[14, 'ARENACAPACITY'] = 18846
df_palazzetti.at[16, 'ARENACAPACITY'] = 20478
df_palazzetti.at[17, 'ARENACAPACITY'] = 17071

# %%
df_palazzetti.at[26, 'MIN_YEAR'] = 2017
df_palazzetti.at[29, 'MIN_YEAR'] = 2019
df_palazzetti.at[12,'MIN_YEAR'] = 2012
df_palazzetti.at[19,'MIN_YEAR'] = 2016
df_palazzetti.at[20,'MIN_YEAR'] = 2002
df_palazzetti.at[24,'MIN_YEAR'] = 2004
df_palazzetti.at[6,'MIN_YEAR'] = 2003
df_palazzetti.at[4,'MIN_YEAR'] = 2001
df_palazzetti.at[10,'MIN_YEAR'] = 2018
df_palazzetti.at[27,'MIN_YEAR'] = 2005
df_palazzetti.at[2,'MIN_YEAR'] = 2007

# %% [markdown]
# Palazzetti non considerati nel dataset

# %%
df_palazzetti['TEAM_ID'] = np.where((df_palazzetti['TEAM_ID']==1610612760) & (df_palazzetti['ABBREVIATION']=='OKC'),1610612770,df_palazzetti['TEAM_ID'])

df_palazzetti['TEAM_ID'] = np.where((df_palazzetti['TEAM_ID']==1610612763) & (df_palazzetti['ABBREVIATION']=='MEM'),1610612769,df_palazzetti['TEAM_ID'])

df_palazzetti['TEAM_ID'] = np.where((df_palazzetti['TEAM_ID']==1610612744) & (df_palazzetti['ABBREVIATION']=='GSW'),1610612767,df_palazzetti['TEAM_ID'])

df_palazzetti['TEAM_ID'] = np.where((df_palazzetti['TEAM_ID']==1610612765) & (df_palazzetti['ABBREVIATION']=='DET'),1610612768,df_palazzetti['TEAM_ID'])

# %%
#Aggiunta dati mancanti
df_palazzetti.loc[30] = ['1610612760', '1995', '2006', 'SEA', 'Sonics','1962','Seattle', 'Climate Pledge Arena','17072.0']
df_palazzetti.loc[31] = ['1610612763', '1995', '2001', 'VAN', 'Grizzlies','1995','Vancouver', 'General Motors Place Pledge Arena','19193.0']
df_palazzetti.loc[32] = ['1610612744', '1971', '2019', 'GSW', 'Warriors','1966','Golden State', 'Oracle Arena','19596.0']
df_palazzetti.loc[33] = ['1610612765', '1988', '2017', 'DET', 'Pistons','1988','Detroit', 'The Palace of Auburn Hills','22076.0']
df_palazzetti.loc[34] = ['1610612771', '1981', '2010', 'NJN', 'Nets', '1980','New Jersey','Izod Center', '20049.0']
df_palazzetti.loc[35] = ['1610612772', '2010', '2012', 'NJN', 'Nets', '2010', 'New Jersey', 'Prudential Center', '18711.0']
df_palazzetti.loc[36] = ['1610612773','1988','2005','CHB', 'Bobcats', '1988', 'Charlotte', 'Charlotte Coliseum', '24042.0']
df_palazzetti.loc[37] = ['1610612774', '1988', '2018', 'MIL', 'Bucks', '1968','Milwaukee', 'Bradley Center', '18717.0']
df_palazzetti.loc[38] = ['1610612775', '1980', '2001', 'DAL', 'Mavericks', '1980', 'Dallas', 'Reunion Arena','18293.0' ]
df_palazzetti.loc[39] = ['1610612776','1975', '2003', 'HOU','Rockets', '1975', 'Houston', 'Central Campus', '16285.0']
df_palazzetti.loc[40] = ['1610612777','2001', '2004','MEM', 'Grizzlies', '2001', 'Memphis', 'Pyramid Arena', '20142.0']
df_palazzetti.loc[41] = ['1610612782', '2001', '2007', 'NOK', 'Pelicans', '2002', 'New Orleans/Oklahoma City', 'Ford Center', '19164.0']
df_palazzetti.loc[42] = ['1610612779', '1993', '2002', 'SAS', 'Spurs', '1993', 'San Antonio', 'Alamodome', '20557.0']
df_palazzetti.loc[43] = ['1610612780', '1988', '2016', 'SAC', 'Kings', '1988', 'Sacramento', 'Sleep Train Arena', '17317.0']
df_palazzetti.loc[44] = ['1610612781', '1988', '2013', 'NOH', 'Hornets', '1988', 'New Orleans', 'Smoothie King Center', '17317.0']

# %%
df_palazzetti['TEAM_ID'] = pd.to_numeric(df_palazzetti['TEAM_ID'])
df_palazzetti['MIN_YEAR'] = pd.to_numeric(df_palazzetti['MIN_YEAR'])
df_palazzetti['MAX_YEAR'] = pd.to_numeric(df_palazzetti['MAX_YEAR'])
df_palazzetti['YEARFOUNDED'] = pd.to_numeric(df_palazzetti['YEARFOUNDED'])
df_palazzetti['ARENACAPACITY'] = df_palazzetti['ARENACAPACITY'].astype(float, errors = 'raise')

# %%
df_palazzetti_fin = df_palazzetti.sort_values(by=['TEAM_ID'])

# %%
df_palazzetti_fin.drop(['YEARFOUNDED', 'NICKNAME'], axis =1)
# Out:
#        TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION                       CITY  \
# 0   1610612737      1949      2022          ATL                    Atlanta
# 1   1610612738      1946      2022          BOS                     Boston
# 28  1610612739      1970      2022          CLE                  Cleveland
# 2   1610612740      2007      2022          NOP                New Orleans
# 3   1610612741      1966      2022          CHI                    Chicago
# 4   1610612742      2001      2022          DAL                     Dallas
# 5   1610612743      1976      2022          DEN                     Denver
# 32  1610612744      1971      2019          GSW               Golden State
# 6   1610612745      2003      2022          HOU                    Houston
# 7   1610612746      1970      2022          LAC                Los Angeles
# 8   1610612747      1948      2022          LAL                Los Angeles
# ...

# %% [markdown]
# Mandiamo su MongoDB

# %%
client = pymongo.MongoClient("mongodb+srv://mfd:ProjectM5@dataman.mwvlz.mongodb.net/?retryWrites=true&w=majority")
db = client.test
mydb = client['dataman']

#invio su mongo 
collection_palazzetti = mydb.palazzetti_fin

palazzetti_finale_mongo =df_palazzetti_fin.to_dict(orient = 'records')

if collection_palazzetti.count_documents({})==0:
    result_palazzetti =mydb.palazzetti_fin.insert_many(palazzetti_finale_mongo)
else:
    result_palazzetti = mydb.palazzetti.drop()
    result_palazzetti =mydb.palazzetti_fin.insert_many(palazzetti_finale_mongo)
